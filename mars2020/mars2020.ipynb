# %%
from turbo_seti.find_event.find_event_pipeline import find_event_pipeline

DATADIR = '/datax/scratch/ewhite/mars2020/'

dat_list = [DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66265_DIAG_Mars2020_0011.rawspec.0000.dat',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66578_DIAG_Mars_0012.rawspec.0000.dat',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66892_DIAG_Mars2020_0013.rawspec.0000.dat',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67205_DIAG_Mars_0014.rawspec.0000.dat',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67519_DIAG_Mars2020_0015.rawspec.0000.dat',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67832_DIAG_Mars_0016.rawspec.0000.dat']

#dat_list = glob.glob(DATADIR + '*.dat')
#print(dat_list)

# This writes the dat files into a .lst, as required by the find_event_pipeline
with open(DATADIR + 'dat_files.lst', 'w') as f:
    for item in dat_list:
        f.write("%s\n" % item)

PATH_CSVF = 'mars_snr10_f3.csv'
event_df = find_event_pipeline(DATADIR + 'dat_files.lst',
                               filter_threshold = 3,
                               on_off_first = 'OFF',
                               number_in_cadence = len(dat_list),
                               user_validation=False,
                               saving=True,
                               csv_name=PATH_CSVF)

event_df
# Out:
# ************   BEGINNING FIND_EVENT PIPELINE   **************
#
# Assuming the first observation is an OFF
# blimpy.io.base_reader WARNING  Selection size of 80.00 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
# find_event_pipeline: source_name = DIAG_Mars2020
# blimpy.io.base_reader WARNING  Selection size of 80.00 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
# find_event_pipeline: source_name = DIAG_Mars
# blimpy.io.base_reader WARNING  Selection size of 80.00 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
# find_event_pipeline: source_name = DIAG_Mars2020
# blimpy.io.base_reader WARNING  Selection size of 80.00 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
# ...

# %%
import glob
from turbo_seti import plot_event
from turbo_seti.find_event.plot_event_pipeline import plot_event_pipeline
# %matplotlib inline

DATADIR = '/datax/scratch/ewhite/mars2020/'
PATH_CSVF = 'mars_snr10_f3.csv'

# We need to create a .lst of the .h5 files, so lets go ahead and do that:
'''filelist = [DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66265_DIAG_Mars2020_0011.rawspec.0000.h5',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66578_DIAG_Mars_0012.rawspec.0000.h5',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66892_DIAG_Mars2020_0013.rawspec.0000.h5',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67205_DIAG_Mars_0014.rawspec.0000.h5',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67519_DIAG_Mars2020_0015.rawspec.0000.h5',
            DATADIR+'spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67832_DIAG_Mars_0016.rawspec.0000.h5']'''

filelist = glob.glob(DATADIR + '*.h5')
filelist.sort()
print(filelist)

# Write file locations to a .lst
with open(DATADIR + 'filelist.lst', 'w') as f:
    for item in filelist:
        f.write("%s\n" % item)

# and finally we plot
#plot_event_pipeline(PATH_CSVF,
#                    DATADIR + 'filelist.lst',
#                    user_validation=True)

# center freq of plot [Mhz]
center = 8411.386337
# distance from center freq [Mhz]
edge = 0.000782
# where to save plots 
path = DATADIR
plot_event.plot_all_hit_and_candidates(DATADIR + 'dat_files.lst', DATADIR + 'filelist.lst', PATH_CSVF,
                                       outdir=path,
                                      c="black", alpha=0.75, window=(center-edge, center+edge))
# Out:
# ['/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66265_DIAG_Mars2020_0011.rawspec.0000.h5', '/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66578_DIAG_Mars_0012.rawspec.0000.h5', '/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66892_DIAG_Mars2020_0013.rawspec.0000.h5', '/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67205_DIAG_Mars_0014.rawspec.0000.h5', '/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67519_DIAG_Mars2020_0015.rawspec.0000.h5', '/datax/scratch/ewhite/mars2020/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_67832_DIAG_Mars_0016.rawspec.0000.h5']
# plot_all_dat: source_name=DIAG_Mars2020
# plot_all_dat: source_name=DIAG_Mars
# plot_all_dat: source_name=DIAG_Mars2020
# ...

# %%
from blimpy import Waterfall
fb = Waterfall('/mnt_blpd18/datax/gb_mars/splices/spliced_blc10111213141516o7o0212223242526o7o031323334353637_guppi_59256_66265_DIAG_Mars2020_0011.rawspec.0000.fil')
#fb = Waterfall('/path/to/filterbank.h5') #works the same way
fb.info()
# Out:
# blimpy.io.base_reader WARNING  Selection size of 80.00 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
#
# --- File Info ---
#       machine_id :                               20
#     telescope_id :                                6
#        data_type :                                1
#             fch1 :               11251.46484375 MHz
#             foff :      -2.7939677238464355e-06 MHz
#           nchans :                       1342177280
#      source_name :                    DIAG_Mars2020
#          src_raj :                          0:00:00
#          src_dej :                          0:00:00
#         az_start :                              0.0
#         za_start :                              0.0
#            nbits :                               32
#    tstart (ISOT) :          2021-02-11T18:24:25.000
#     tstart (MJD) :                59256.76695601852
# ...
